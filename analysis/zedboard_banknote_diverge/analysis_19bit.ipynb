# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# Out:
# Requirement already satisfied: pandas in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.14.0)
# Requirement already satisfied: matplotlib in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib) (20.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (7.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.15.0)
# Requirement already satisfied: scipy in /home/administrator@physics.ad.cloud.unipg.it/.local/lib/python3.8/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.23.3)

# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.stats import norm

# %%
class colors:
    WHITE = '\033[97m'
    BLACK = '\033[90m'
    HEADER = '\033[95m'
    BLUE = '\033[94m'
    CYAN = '\033[96m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    
def blue(text):
    return colors.BLUE+text+colors.BLACK

def green(text):
    return colors.GREEN+text+colors.BLACK

def red(text):
    return colors.RED+text+colors.BLACK

def yellow(text):
    return colors.YELLOW+text+colors.BLACK

# %%
def load_run(runname):
    rundata=pd.read_csv(runname+'.csv')
    
    with open(runname+'_report.json') as f:
        runinfo=json.load(f)

    if 'clock_freq' in runinfo:
        clock_freq=runinfo['clock_freq']
    else:
        clock_freq=None

    if 'clock_cycles' in rundata:
        clock_mean=rundata['clock_cycles'].mean()
        clock_std=rundata['clock_cycles'].std()
        inference_time_mean=clock_mean/(clock_freq)
        
        fig, ax = plt.subplots(1, 3, gridspec_kw={'width_ratios': [3, 1, 2]}, figsize=(15, 4))
            
        ax[0].set_title("Clock cicles distribution")
        ax[0].set_facecolor('#aaaaaa')
        rundata.plot.hist(ax=ax[0],column=["clock_cycles"], bins=50,density=True)
        x = np.linspace(0, 20000, 100)
        p = norm.pdf(x, clock_mean, clock_std)
        #ax[0].plot(x, p, 'k', linewidth=2)
        
        ax[1].set_title("Run report")
        ax[1].set_axis_off()
        pos=0.9
        for key,value in sorted(runinfo.items()):
            ax[1].text(0.0, pos, key+": "+str(value))
            pos-=0.1
        ax[1].text(0.0, pos, "clock_mean: "+str(clock_mean)[:10])
        pos-=0.1
        ax[1].text(0.0, pos, "clock_std: "+str(clock_std)[:10])
        pos-=0.1
        ax[1].text(0.0, pos, "inference_time_mean: "+str(inference_time_mean)[:10]+" us")

        ax[2].set_title("BondMachine diagram")
        ax[2].set_axis_off()
        img = mpimg.imread(runname+'_image.png')
        ax[2].imshow(img)
        
    else:
        clock_mean=None
        clock_std=None
        inference_time_mean=None
        
    runinfo["runname"]=runname
    runinfo["rundata"]=rundata
    runinfo["clock_freq"]=clock_freq
    runinfo["clock_mean"]=clock_mean
    runinfo["clock_std"]=clock_std
    runinfo["inference_time_mean"]=inference_time_mean
    
    return runinfo

# %%
def runplot(runs, pivot_run, x_param, y_param, title):
    x=[]
    y=[]
    names=[]
    for i in range(len(runs)):
        if x_param in runs[i] and y_param in runs[i]:
            x.append(runs[i][x_param])
            y.append(runs[i][y_param])
            names.append(runs[i]["runname"])

    if len(names) < 2:
        print ("Not enought data to plot")
        return
            
    fig, ax = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]}, figsize=(15, 4))
    
    style = dict(size=10, color='black')
    
    if title != None:
        ax[0].set_title(title)
    else:
        ax[0].set_title(x_param + " vs "+ y_param)
    ax[0].set_facecolor('#ffffff')
    #for i in range(len(runs)):
    #    if x_param in runs[i] and y_param in runs[i]:            
    #        ax[0].text(runs[i][x_param], runs[i][y_param], runs[i]["runname"], **style)
    ax[0].plot(x, y ,linewidth=2, marker='o', color='b')
    ax[0].set_xlabel('Exponent')
    ax[0].set_ylabel('Inference time mean')

    ax[1].set_title("Data")
    ax[1].set_axis_off()
    pos=0.9
    ax[1].text(0.0, pos, "run name - "+x_param+" - "+y_param)
    pos-=0.1
    for i in range(len(names)):
        ax[1].text(0.0, pos, names[i]+" - "+str(x[i])+" - "+str(y[i]))
        pos-=0.1
        
    display(fig)
    plt.close()

# %%
def consistency(runs, pivot_run):
    # Result consistency, compare to pivot run every other run by mean and std
    for i in range(len(runs)):
        if i!= pivot_run:
            runname=runs[i]["runname"]
            rundata0=abs(runs[i]["rundata"]["probability_0"]-runs[pivot_run]["rundata"]["probability_0"])
            rundata0_mean=rundata0.mean()
            rundata0_std=rundata0.std()
            rundata1=abs(runs[i]["rundata"]["probability_1"]-runs[pivot_run]["rundata"]["probability_1"])
            rundata1_mean=rundata1.mean()
            rundata1_std=rundata1.std()
            prediction=runs[i]["rundata"]["classification"]==runs[pivot_run]["rundata"]["classification"]
           
            print (blue(runname)+" - probability_0 - mean: "+str(rundata0_mean)+ " std: "+str(rundata0_std))
            print (blue(runname)+" - probability_1 - mean: "+str(rundata1_mean)+ " std: "+str(rundata1_std))
            print (blue(runname)+" - prediction    - "+ green(str(prediction.value_counts(normalize=True)[True]*100)+ "%")+" equal")
            print ()

# %%
def analyze(runs, pivot_run):
    pivot_name=runs[pivot_run]["runname"]
    print ("Pivot run "+ blue(pivot_name))
    print ()
    print (red("Consistency, compare to pivot run every other run"))
    consistency(runs, pivot_run)
    
    print (red("Inference time mean"))
    runplot(runs, pivot_run, "expprec", "inference_time_mean", "")
    
#     print (red("Occupancy"))
#     runplot(runs, pivot_run, "cps", "luts", "Occupancy (cps vs luts)")

#     print (red("Power consumption"))
#     runplot(runs, pivot_run, "cps", "power", "Power consumption (cps vs power)")

# %%
soft=load_run("sw")

# %%
expanded=load_run("expanded")

# %%
proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit")

# %%
proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit=load_run("proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit")

# %%
analyze([ soft, proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit,
          proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit, 
          proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit, 
          proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit,
          proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit ,
          proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit, 
          proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit,
          proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit, 
          proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit],0)
# Out:
# Pivot run sw
#
# Consistency, compare to pivot run every other run
# proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit - probability_0 - mean: 0.12298629203636365 std: 0.4437038346002834
# proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit - probability_1 - mean: 0.0990879302909091 std: 0.16432022625431436
# proj_zedboard_diverge_mm_hwopt_expprec1_flopoco_19bit - prediction    - 99.63636363636364% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit - probability_0 - mean: 0.0193987964 std: 0.02325941408620505
# proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit - probability_1 - mean: 0.019398400545454546 std: 0.02325143079667957
# proj_zedboard_diverge_mm_hwopt_expprec2_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit - probability_0 - mean: 0.0054021396 std: 0.009094798575205223
# proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit - probability_1 - mean: 0.005406650290909092 std: 0.00909794063039526
# proj_zedboard_diverge_mm_hwopt_expprec3_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit - probability_0 - mean: 0.0002485682545454503 std: 0.00041605595958265333
# proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit - probability_1 - mean: 0.0002516501454545457 std: 0.0004182685867528348
# proj_zedboard_diverge_mm_hwopt_expprec5_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit - probability_0 - mean: 0.00010801647272726851 std: 7.45621628345399e-05
# proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit - probability_1 - mean: 9.9151090909089e-05 std: 8.463245489859962e-05
# proj_zedboard_diverge_mm_hwopt_expprec8_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit - probability_0 - mean: 0.00010801647272726851 std: 7.45621628345399e-05
# proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit - probability_1 - mean: 9.9151090909089e-05 std: 8.463245489859962e-05
# proj_zedboard_diverge_mm_hwopt_expprec10_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit - probability_0 - mean: 0.00010801647272726851 std: 7.45621628345399e-05
# proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit - probability_1 - mean: 9.9151090909089e-05 std: 8.463245489859962e-05
# proj_zedboard_diverge_mm_hwopt_expprec13_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit - probability_0 - mean: 0.00010801647272726851 std: 7.45621628345399e-05
# proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit - probability_1 - mean: 9.9151090909089e-05 std: 8.463245489859962e-05
# proj_zedboard_diverge_mm_hwopt_expprec16_flopoco_19bit - prediction    - 100.0% equal
#
# proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit - probability_0 - mean: 0.00010801647272726851 std: 7.45621628345399e-05
# proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit - probability_1 - mean: 9.9151090909089e-05 std: 8.463245489859962e-05
# proj_zedboard_diverge_mm_hwopt_expprec20_flopoco_19bit - prediction    - 100.0% equal
#
# Inference time mean
